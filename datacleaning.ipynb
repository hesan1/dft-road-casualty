# %%
import pandas as pd

# %%
df = pd.read_csv("dft-road-casualty-statistics-casualty-provisional-mid-year-unvalidated-2022 (1).csv")

# %%
df
# Out:
#             status accident_index  accident_year accident_reference  \
# 0      Unvalidated  2022070151244           2022          070151244
# 1      Unvalidated  2022070152668           2022          070152668
# 2      Unvalidated  2022070154696           2022          070154696
# 3      Unvalidated  2022070154696           2022          070154696
# 4      Unvalidated  2022070154696           2022          070154696
# ...            ...            ...            ...                ...
# 61347  Unvalidated  2022461156711           2022          461156711
# 61348  Unvalidated  2022461157243           2022          461157243
# 61349  Unvalidated  2022461157256           2022          461157256
# 61350  Unvalidated  2022461157316           2022          461157316
# 61351  Unvalidated  2022461159841           2022          461159841
#
#        vehicle_reference  casualty_reference  casualty_class  sex_of_casualty  \
# ...

# %%
df = df.drop(['status', 'accident_year'], axis=1)

# %%
df
# Out:
#       accident_index accident_reference  vehicle_reference  \
# 0      2022070151244          070151244                  2
# 1      2022070152668          070152668                  1
# 2      2022070154696          070154696                  1
# 3      2022070154696          070154696                  2
# 4      2022070154696          070154696                  3
# ...              ...                ...                ...
# 61347  2022461156711          461156711                  1
# 61348  2022461157243          461157243                  1
# 61349  2022461157256          461157256                  2
# 61350  2022461157316          461157316                  1
# 61351  2022461159841          461159841                  2
#
#        casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 0                       1               1                2               46
# 1                       1               1                1               30
# ...

# %%
for column in df.columns:
    df = df[df[column] != -1]

# %%
df
# Out:
#       accident_index accident_reference  vehicle_reference  \
# 0      2022070151244          070151244                  2
# 1      2022070152668          070152668                  1
# 2      2022070154696          070154696                  1
# 3      2022070154696          070154696                  2
# 4      2022070154696          070154696                  3
# ...              ...                ...                ...
# 61346  2022461156575          461156575                  1
# 61347  2022461156711          461156711                  1
# 61349  2022461157256          461157256                  2
# 61350  2022461157316          461157316                  1
# 61351  2022461159841          461159841                  2
#
#        casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 0                       1               1                2               46
# 1                       1               1                1               30
# ...

# %%
# Check for null values
null_values = df.isnull().sum()
print("Null Values:\n", null_values)

# Check for duplicates
duplicates = df.duplicated()
print("\nNumber of Duplicates:", duplicates.sum())
# Out:
# Null Values:
#  accident_index                        0
# accident_reference                    0
# vehicle_reference                     0
# casualty_reference                    0
# casualty_class                        0
# sex_of_casualty                       0
# age_of_casualty                       0
# age_band_of_casualty                  0
# casualty_severity                     0
# pedestrian_location                   0
# pedestrian_movement                   0
# car_passenger                         0
# bus_or_coach_passenger                0
# pedestrian_road_maintenance_worker    0
# casualty_type                         0
# casualty_home_area_type               0
# casualty_imd_decile                   0
# lsoa_of_casualty                      0
# dtype: int64
#
# Number of Duplicates: 0

# %%
# Display unique values for each column
for column in df.columns:
    unique_values = df[column].unique()
    print(f"\nUnique values in {column}:\n", unique_values)
# Out:
# Unique values in accident_index:
#  ['2022070151244' '2022070152668' '2022070154696' ... '2022461156711'
#  '2022461157256' '2022461157316']
#
# Unique values in accident_reference:
#  ['070151244' '070152668' '070154696' ... '461156711' '461157256'
#  '461157316']
#
# Unique values in vehicle_reference:
#  [  2   1   3   4   5   8   6   9 227   7  61]
#
# Unique values in casualty_reference:
#  [  1   3   2   4   5   6   7   8   9  10  11  12  14  15  16  13  22 148]
#
# Unique values in casualty_class:
#  [1 3 2]
#
# Unique values in sex_of_casualty:
#  [2 1 9]
#
# Unique values in age_of_casualty:
#  [ 46  30  58  78  63  52  74  50  79  13  48  45  28  54  42  33  34   7
#   20  18  16  80  14  19  32  59  36  84  23  43   5  31  25  21  72  15
#   22  47  86  76  61  35  51  17  68  38  73  65  27  66  93  77  60  69
#   41  67  91  70  24  40  29  55  57  53  26  81  39  37  12   8  62  64
#   10  49   6  75  92   3  56  44  11  71  82   9   4   2  87   0   1  83
# ...

# %%
df
# Out:
#       accident_index accident_reference  vehicle_reference  \
# 0      2022070151244          070151244                  2
# 1      2022070152668          070152668                  1
# 2      2022070154696          070154696                  1
# 3      2022070154696          070154696                  2
# 4      2022070154696          070154696                  3
# ...              ...                ...                ...
# 61346  2022461156575          461156575                  1
# 61347  2022461156711          461156711                  1
# 61349  2022461157256          461157256                  2
# 61350  2022461157316          461157316                  1
# 61351  2022461159841          461159841                  2
#
#        casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 0                       1               1                2               46
# 1                       1               1                1               30
# ...

# %%
# Assuming your DataFrame is named 'df'
df = df[~df['vehicle_reference'].isin([227, 61])]
df = df[~df['casualty_reference'].isin([22, 148])]

# %%
df
# Out:
#       accident_index accident_reference  vehicle_reference  \
# 0      2022070151244          070151244                  2
# 1      2022070152668          070152668                  1
# 2      2022070154696          070154696                  1
# 3      2022070154696          070154696                  2
# 4      2022070154696          070154696                  3
# ...              ...                ...                ...
# 61346  2022461156575          461156575                  1
# 61347  2022461156711          461156711                  1
# 61349  2022461157256          461157256                  2
# 61350  2022461157316          461157316                  1
# 61351  2022461159841          461159841                  2
#
#        casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 0                       1               1                2               46
# 1                       1               1                1               30
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Display distribution and relationships for Casualty_Class, Sex_of_Casualty, Age_of_Casualty, Age_Band_of_Casualty, Casualty_Severity
selected_columns = ['casualty_class', 'sex_of_casualty', 'age_of_casualty', 'age_band_of_casualty', 'casualty_severity']
for column in selected_columns:
    print(f"\n{column} - Value Counts:\n", df[column].value_counts())
    sns.countplot(x=column, data=df)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()
# Out:
# casualty_class - Value Counts:
#  casualty_class
# 1    37303
# 2     9291
# 3     7689
# Name: count, dtype: int64
# sex_of_casualty - Value Counts:
#  sex_of_casualty
# 1    33430
# 2    20847
# 9        6
# Name: count, dtype: int64
# age_of_casualty - Value Counts:
#  age_of_casualty
# 18     1442
# 19     1390
# 21     1294
# 20     1247
# 31     1247
#        ...
# 96        4
# 99        4
# 97        2
# 98        2
# 101       1
# Name: count, Length: 101, dtype: int64
# age_band_of_casualty - Value Counts:
#  age_band_of_casualty
# 6     11644
# 7      8575
# 8      7208
# 5      6048
# 4      5696
# 9      5314
# 10     2717
# 3      2626
# 11     2267
# 2      1351
# 1       837
# Name: count, dtype: int64
# casualty_severity - Value Counts:
#  casualty_severity
# 3    43136
# 2    10490
# 1      657
# Name: count, dtype: int64

# %%
# Display distribution for Pedestrian_Location, Pedestrian_Movement, Car_Passenger, Bus_or_Coach_Passenger, Pedestrian_Road_Maintenance_Worker
selected_columns = ['pedestrian_location', 'pedestrian_movement', 'car_passenger', 'bus_or_coach_passenger', 'pedestrian_road_maintenance_worker']
for column in selected_columns:
    print(f"\n{column} - Value Counts:\n", df[column].value_counts())
    sns.countplot(x=column, data=df)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()
# Out:
# pedestrian_location - Value Counts:
#  pedestrian_location
# 0     46594
# 5      2867
# 1      1279
# 6       930
# 9       806
# 10      712
# 8       503
# 4       477
# 7        51
# 2        35
# 3        29
# Name: count, dtype: int64
# pedestrian_movement - Value Counts:
#  pedestrian_movement
# 0    46593
# 1     2451
# 9     2179
# 3     1560
# 5      424
# 2      360
# 4      276
# 7      200
# 8      193
# 6       47
# Name: count, dtype: int64
# car_passenger - Value Counts:
#  car_passenger
# 0    46239
# 1     5136
# 2     2888
# 9       20
# Name: count, dtype: int64
# bus_or_coach_passenger - Value Counts:
#  bus_or_coach_passenger
# 0    53591
# 4      392
# 3      232
# 2       40
# 1       25
# 9        3
# Name: count, dtype: int64
# pedestrian_road_maintenance_worker - Value Counts:
#  pedestrian_road_maintenance_worker
# 0    53282
# 2      894
# 1      107
# Name: count, dtype: int64

# %%
# Display distribution for Casualty_Type, Casualty_Home_Area_Type
selected_columns = ['casualty_type', 'casualty_home_area_type']
for column in selected_columns:
    print(f"\n{column} - Value Counts:\n", df[column].value_counts())
    sns.countplot(x=column, data=df)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()
# Out:
# casualty_type - Value Counts:
#  casualty_type
# 9     28994
# 0      7689
# 1      6375
# 3      3358
# 5      1633
# 19     1312
# 11      782
# 97      779
# 4       754
# 90      723
# 8       562
# 2       378
# 98      376
# 21      152
# 23      114
# 22      103
# 10       74
# 20       69
# 16       28
# 17       27
# 18        1
# Name: count, dtype: int64
# casualty_home_area_type - Value Counts:
#  casualty_home_area_type
# 1    43960
# 3     5847
# 2     4476
# Name: count, dtype: int64

# %%
# Select numerical columns for correlation analysis
numerical_columns = ['age_of_casualty', 'casualty_severity']

# Calculate correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Visualize the correlation matrix using a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Select all numerical columns for correlation analysis
all_numerical_columns = df.select_dtypes(include='number').columns

# Calculate correlation matrix
correlation_matrix_all = df[all_numerical_columns].corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix_all, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()
